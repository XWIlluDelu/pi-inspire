# %% [markdown]
# # Observation window
#
# A compact analysis of the latest **24 samples** from Station 07.

# %%
summary = {
    "temperature_c": 18.4,
    "humidity_pct": 62,
    "samples": 24,
}
summary
# Out:
# {'temperature_c': 18.4, 'humidity_pct': 62, 'samples': 24}

# %%
print("24/24 samples passed continuity checks")
# Out:
# 24/24 samples passed continuity checks

# %%
render_summary(summary)
# Out:
# ### Result
# The window is internally consistent; no reset signature was detected.
