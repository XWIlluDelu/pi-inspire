# %% [markdown]
# # Notebook image preview
#
# [Report](document-images.md#results)
#
# ![Notebook file image](training%20curve.png)
#
# ![Notebook attachment](attachment:curve.png)

# %%
# Static fixture; no execution
# Out:
# ## Output Markdown
#
# ![Output pipeline](vector.svg)
